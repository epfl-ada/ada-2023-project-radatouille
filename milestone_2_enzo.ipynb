# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import ast

# %%
cmu_movies = pd.read_csv('data/cmu_movies.csv', sep='\t')
metacritic_reviews = pd.read_csv('data/scrap/metacritic_reviews.csv')
imdb_reviews = pd.read_csv('data/title.ratings.tsv', sep='\t')
wikidata_awards = pd.read_csv('data/scrap/wikidata_awards.csv')
imdb_awards = pd.read_csv('data/scrap/imdb_awards.csv')

# %%
metacritic_reviews
# Out:
#                   publisher              author  metacritic_rating  metascore  \
# 0               L.A. Weekly        Paul Malcolm               80.0       35.0
# 1          New Times (L.A.)    Gregory Weinkauf               80.0       35.0
# 2         Chicago Sun-Times         Roger Ebert               75.0       35.0
# 3           Chicago Tribune  Michael Wilmington               63.0       35.0
# 4                     Salon      Andrew O'Hehir               60.0       35.0
# ...                     ...                 ...                ...        ...
# 159014  New York Daily News        Joe Neumaier               60.0       65.0
# 159015                  NPR        Scott Tobias               60.0       65.0
# 159016   The New York Times      Manohla Dargis               60.0       65.0
# 159017       Slant Magazine          Bill Weber               50.0       65.0
# 159018             Time Out          David Fear               40.0       65.0
#
#                metacritic_id
# ...

# %%
# Filter movies with metacritic reviews and freebase id
alldata_movies = cmu_movies.loc[(cmu_movies['imdb_id'].isin(imdb_reviews['tconst'])) & (cmu_movies['metacritic_id'].isin(metacritic_reviews['metacritic_id']))]

alldata_movies_merged = pd.merge(alldata_movies, imdb_reviews, left_on='imdb_id', right_on='tconst').drop(columns=['tconst'])

# Average metacritic score
metacritic_reviews_metascores = metacritic_reviews.groupby('metacritic_id').head(1).drop(columns=['author', 'publisher', 'metacritic_rating'])

alldata_movies_merged = pd.merge(alldata_movies_merged, metacritic_reviews_metascores, left_on='metacritic_id', right_on='metacritic_id')

# %%
alldata_movies_merged
# Out:
#       wikipedia_id freebase_id                   title release_date  \
# 0           975900   /m/03vyhn          Ghosts of Mars   2001-08-24
# 1           171005   /m/016ywb                 Henry V   1989-11-08
# 2            77856    /m/0kcn7            Mary Poppins   1964-08-27
# 3           612710   /m/02wjqm          New Rose Hotel   1999-10-01
# 4         21926710  /m/05p45cv           White on Rice         2009
# ...            ...         ...                     ...          ...
# 8043      25920477  /m/0b6lqyd             Source Code   2011-03-11
# 8044       4492078   /m/0c5clj  How to Eat Fried Worms   2006-08-25
# 8045         54540    /m/0f7hw       Coming to America   1988-06-29
# 8046       1918494   /m/0660qx          State and Main   2000-08-26
# 8047      34980460  /m/0g4pl34                 Knuckle   2011-01-21
#
#           revenue  runtime                                          languages  \
# ...

# %%
sns.scatterplot(x="metascore", y="averageRating", data=alldata_movies_merged)
plt.title("Rating vs Metascore")
plt.xticks(range(0, 101, 10))
plt.yticks(range(0, 11, 1))
plt.xlim(0, 100)
plt.ylim(0, 10)
plt.xlabel("Metascore")
plt.ylabel("Users Rating")
plt.grid()

# plot center lines
plt.axhline(y=5, color='k', linestyle='-', alpha=0.5)
plt.axvline(x=50, color='k', linestyle='-', alpha=0.5)

# plot mean lines
plt.axhline(y=alldata_movies_merged['averageRating'].mean(), color='b', linestyle='-')
plt.axvline(x=alldata_movies_merged['metascore'].mean(), color='b', linestyle='-')

# plot median lines
plt.axhline(y=alldata_movies_merged['averageRating'].median(), color='r', linestyle='-')
plt.axvline(x=alldata_movies_merged['metascore'].median(), color='r', linestyle='-')

# legend the lines but not the scatter plots
import matplotlib.lines as mlines
blue_line = mlines.Line2D([], [], color='blue', label='Mean')
red_line = mlines.Line2D([], [], color='red', label='Median')
plt.legend(handles=[blue_line, red_line])

plt.show()

# %%
sns.pairplot(alldata_movies_merged[['metascore_avg', 'averageRating', 'numVotes', 'revenue', 'runtime']])

# %%
sns.scatterplot(y="revenue", x="averageRating", data=alldata_movies_merged)
# Out:
# <Axes: xlabel='averageRating', ylabel='revenue'>

# %% [markdown]
# ## Publisher Ratings Analysis

# %%
top_publishers = metacritic_reviews \
    .groupby('publisher') \
    .agg({'rating': ['count']}) \
    .sort_values(by=[('rating', 'count')], ascending=False) \
    .head(20) \
    .reset_index() \
    ['publisher']

# %%
# create one subplot for each publisher
fig, axs = plt.subplots(len(top_publishers) // 5, 5, figsize=( 20, (len(top_publishers) // 5) * 5))

# plot the distribution of ratings for each publisher
for i, publisher in enumerate(top_publishers):
    ax = axs[i // 5][i % 5]
    ax.set_title(publisher)
    sns.histplot(metacritic_reviews.loc[metacritic_reviews['publisher'] == publisher]['rating'], ax=ax)
    ax.set_xlim(0, 100)

plt.show()

# %%
merged_metacritic_reviews = metacritic_reviews.merge(cmu_movies.loc[(cmu_movies['metacritic_id'].isin(metacritic_reviews['metacritic_id'])) & ~(cmu_movies['metacritic_id'].isna()), ('metacritic_id', 'genres')], on='metacritic_id', how='left')

# %%
# Assuming 'merged_metacritic_reviews' is your DataFrame
def extract_genres(row):
    try:
        genres_dict = ast.literal_eval(row['genres'])
        return list(genres_dict.values())
    except:
        return []
    

# Apply the function to extract genres
merged_metacritic_reviews['extracted_genres'] = merged_metacritic_reviews.apply(extract_genres, axis=1)

# Explode the DataFrame to have a separate row for each genre
exploded_df = merged_metacritic_reviews.explode('extracted_genres')

# Group by genre and calculate mean and count of ratings
grouped_df = exploded_df.groupby('extracted_genres').agg({'rating': ['mean', 'count']})

# Sort by the count of ratings and take the top 10
top_genres = grouped_df.sort_values(by=('rating', 'mean'), ascending=False).head(10)

# %%
# select one occurence per movie
exploded_df.groupby('extracted_genres').agg({'rating': ['mean', 'count']}).sort_values(by=('rating', 'mean'), ascending=False)
# Out:
#                             rating
#                               mean count
# extracted_genres
# Propaganda film          94.772727    22
# Jungle Film              93.866667    15
# Mockumentary             91.966667    30
# Alien invasion           90.687500    16
# Sword and sorcery films  89.885965   114
# ...                            ...   ...
# Live action              49.846154    13
# Film à clef              43.922078    77
# Star vehicle             40.384615    39
# Demonic child            38.023256    43
# Legal drama              37.454545    44
#
# [209 rows x 2 columns]

# %%
#kepping unique metracritic_id on metacritic_reviews
metacritic_reviews_unique = metacritic_reviews.drop_duplicates(subset=['metacritic_id'])

#Adding metascore from metacritic_reviews to cmu_movies
cmu_movies = cmu_movies.merge(metacritic_reviews_unique[['metacritic_id', 'metascore']], on='metacritic_id', how='left')
display(cmu_movies)
# Out:
#        wikipedia_id freebase_id  \
# 0            975900   /m/03vyhn
# 1           3196793   /m/08yl5d
# 2          28463795  /m/0crgdbh
# 3           9363483  /m/0285_cd
# 4            261236   /m/01mrr1
# ...             ...         ...
# 81736      35228177  /m/0j7hxnt
# 81737      34980460  /m/0g4pl34
# 81738       9971909  /m/02pygw1
# 81739        913762   /m/03pcrp
# 81740      12476867  /m/02w7zz8
#
#                                                    title release_date  \
# 0                                         Ghosts of Mars   2001-08-24
# 1      Getting Away with Murder: The JonBenét Ramsey ...   2000-02-16
# 2                                            Brun bitter         1988
# 3                                       White Of The Eye         1987
# 4                                      A Woman in Flames         1983
# ...                                                  ...          ...
# 81736                           Mermaids: The Body Found   2011-03-19
# ...

# %%
#Add in cmu_movies award and nomination count
cmu_movies = cmu_movies.merge(imdb_awards, on='freebase_id', how='left')
display(cmu_movies)
# Out:
#        wikipedia_id freebase_id  \
# 0            975900   /m/03vyhn
# 1           3196793   /m/08yl5d
# 2          28463795  /m/0crgdbh
# 3           9363483  /m/0285_cd
# 4            261236   /m/01mrr1
# ...             ...         ...
# 81736      35228177  /m/0j7hxnt
# 81737      34980460  /m/0g4pl34
# 81738       9971909  /m/02pygw1
# 81739        913762   /m/03pcrp
# 81740      12476867  /m/02w7zz8
#
#                                                    title release_date  \
# 0                                         Ghosts of Mars   2001-08-24
# 1      Getting Away with Murder: The JonBenét Ramsey ...   2000-02-16
# 2                                            Brun bitter         1988
# 3                                       White Of The Eye         1987
# 4                                      A Woman in Flames         1983
# ...                                                  ...          ...
# 81736                           Mermaids: The Body Found   2011-03-19
# ...

# %%
#rename type_awards to count_awards and type_nominations to count_nominations
cmu_movies.rename(columns={'wins': 'count_award', 'nominations': 'count_nomination'}, inplace=True)

# %%
#plot metascore vs nb awards
sns.scatterplot(x="metascore", y="count_award", data=cmu_movies)
sns.scatterplot(x="metascore", y="count_nomination", data=cmu_movies)
plt.title("Metascore vs Awards")
plt.ylabel("Count")
plt.xlabel("Metascore")
plt.legend(['Awards', 'Nominations'])
# Out:
# /Users/enzo/anaconda3/envs/ada/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/enzo/anaconda3/envs/ada/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/enzo/anaconda3/envs/ada/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
#We can also plot the number of awards by genre, language and coutries
#First we prepapare the data
def extract_genres(row, type):
    try:
        genres_dict = ast.literal_eval(row[type])
        return list(genres_dict.values())
    except:
        return []
    
# Apply the function to extract genres
cmu_movies['extracted_genres'] = cmu_movies.apply(extract_genres, axis=1, args=('genres',))
cmu_movies['extracted_language'] = cmu_movies.apply(extract_genres, axis=1, args=('languages',))
cmu_movies['extracted_country'] = cmu_movies.apply(extract_genres, axis=1, args=('countries',))

# Explode the DataFrame to have a separate row for each genre
exploded_genres_df = cmu_movies.explode('extracted_genres')
exploded_language_df = cmu_movies.explode('extracted_language')
exploded_country_df = cmu_movies.explode('extracted_country')

# %%
#now we can plot
#Group by and compute the mean of awards and nominations
grouped_genres_df = exploded_genres_df.groupby('extracted_genres').agg({'count_award': ['count', 'mean'], 'count_nomination': ['count', 'mean']})
grouped_language_df = exploded_language_df.groupby('extracted_language').agg({'count_award': ['count', 'mean'], 'count_nomination': ['count', 'mean']})
grouped_country_df = exploded_country_df.groupby('extracted_country').agg({'count_award': ['count', 'mean'], 'count_nomination': ['count', 'mean']})
display(grouped_country_df)
# Out:
#                   count_award            count_nomination
#                         count       mean            count       mean
# extracted_country
# Afghanistan                 4   6.250000                4   4.500000
# Albania                     1   4.000000                1   6.000000
# Algeria                     5   7.200000                5   9.000000
# Argentina                  56  10.857143               56  10.250000
# Armenia                     1   8.000000                1   4.000000
# ...                       ...        ...              ...        ...
# Weimar Republic             2   3.000000                2   3.000000
# West Germany               21   7.190476               21   5.428571
# Yugoslavia                  4   6.500000                4   3.000000
# Zambia                      0        NaN                0        NaN
# Zimbabwe                    0        NaN                0        NaN
#
# [147 rows x 4 columns]

# %%
def plot_awards_vs(df, name):
    #plot top 20 genres
    fig, axs = plt.subplots(2, 2, figsize=(20, 10))
    df = df.sort_values(by=('count_award', 'mean'), ascending=False)
    sns.barplot(ax=axs[0,0], x=df.head(30).index, y=('count_award', 'mean'), data=df.head(30))
    #rotate xlabel
    axs[0,0].set_xticklabels(axs[0,0].get_xticklabels(), rotation=90)
    axs[0,0].set_title("Average Awards by "+name)
    axs[0,0].set_ylabel("Average Awards")
    axs[0,0].set_xlabel(name)

    df = df.sort_values(by=('count_award', 'count'), ascending=False)
    sns.barplot(ax=axs[0,1], x=df.head(30).index, y=('count_award', 'count'), data=df.head(30))
    axs[0,1].set_xticklabels(axs[0,1].get_xticklabels(), rotation=90)
    axs[0,1].set_title("Number of Awards by "+name)
    axs[0,1].set_ylabel("Number of Awards")
    axs[0,1].set_xlabel(name)

    df = df.sort_values(by=('count_nomination', 'mean'), ascending=False)
    sns.barplot(ax=axs[1,0], x=df.head(30).index, y=('count_nomination', 'mean'), data=df.head(30))
    axs[1,0].set_xticklabels(axs[1,0].get_xticklabels(), rotation=90)
    axs[1,0].set_title("Average Nominations by " + name)
    axs[1,0].set_ylabel("Average Nominations")
    axs[1,0].set_xlabel(name)

    df = df.sort_values(by=('count_nomination', 'count'), ascending=False)
    sns.barplot(ax=axs[1,1], x=df.head(30).index, y=('count_nomination', 'count'), data=df.head(30))
    axs[1,1].set_xticklabels(axs[1,1].get_xticklabels(), rotation=90)
    axs[1,1].set_title("Number of Nominations by " + name)
    axs[1,1].set_ylabel("Number of Nominations")
    axs[1,1].set_xlabel(name)

    #resized the plot
    fig.tight_layout()

# %%
#plot top 20 genres
plot_awards_vs(grouped_genres_df, 'Genres')
# Out:
# /Users/enzo/anaconda3/envs/ada/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/enzo/anaconda3/envs/ada/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/enzo/anaconda3/envs/ada/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
#plot top 20 countries
plot_awards_vs(grouped_country_df, 'Countries')
# Out:
# /Users/enzo/anaconda3/envs/ada/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/enzo/anaconda3/envs/ada/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/enzo/anaconda3/envs/ada/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
#plot top 20 languages
plot_awards_vs(grouped_language_df, 'Languages')
# Out:
# /Users/enzo/anaconda3/envs/ada/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/enzo/anaconda3/envs/ada/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/enzo/anaconda3/envs/ada/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...
